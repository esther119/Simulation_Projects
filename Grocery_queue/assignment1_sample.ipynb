# %% [markdown]
# # Visualize an M/G/1 queue

# %% [markdown]
# We first replace the `arrival_rate` and `service_rate` parameters with `arrival_distribution` and `service_distribution` parameters so we can generate samples from them during the simulation. This makes the simulation more general since we can pass in _any_ distribution as a parameter.

# %% [markdown]
# ## Event and Schedule classes: Unchanged

# %%
import heapq

class Event:
    '''
    Store the properties of one event in the Schedule class defined below. Each
    event has a time at which it needs to run, a function to call when running
    the event, along with the arguments and keyword arguments to pass to that
    function.
    '''
    def __init__(self, timestamp, function, *args, **kwargs):
        self.timestamp = timestamp
        self.function = function
        self.args = args
        self.kwargs = kwargs

    def __lt__(self, other):
        '''
        This overloads the less-than operator in Python. We need it so the
        priority queue knows how to compare two events. We want events with
        earlier (smaller) times to go first.
        '''
        return self.timestamp < other.timestamp

    def run(self, schedule):
        '''
        Run an event by calling the function with its arguments and keyword
        arguments. The first argument to any event function is always the
        schedule in which events are being tracked. The schedule object can be
        used to add new events to the priority queue.
        '''
        self.function(schedule, *self.args, **self.kwargs)


class Schedule:
    '''
    Implement an event schedule using a priority queue. You can add events and
    run the next event.
    
    The `now` attribute contains the time at which the last event was run.
    '''
    
    def __init__(self):
        self.now = 0  # Keep track of the current simulation time
        self.priority_queue = []  # The priority queue of events to run
    
    def add_event_at(self, timestamp, function, *args, **kwargs):
        # Add an event to the schedule at a particular point in time.
        heapq.heappush(
            self.priority_queue,
            Event(timestamp, function, *args, **kwargs))
    
    def add_event_after(self, interval, function, *args, **kwargs):
        # Add an event to the schedule after a specified time interval.
        self.add_event_at(self.now + interval, function, *args, **kwargs)
    
    def next_event_time(self):
        return self.priority_queue[0].timestamp

    def run_next_event(self):
        # Get the next event from the priority queue and run it.
        event = heapq.heappop(self.priority_queue)
        self.now = event.timestamp
        event.run(self)
        
    def __repr__(self):
        return (
            f'Schedule() at time {self.now} ' +
            f'with {len(self.priority_queue)} events in the queue')
    
    def print_events(self):
        print(repr(self))
        for event in sorted(self.priority_queue):
            print(f'   {event.timestamp}: {event.function.__name__}')

# %% [markdown]
# ## Queue and BusSystem classes
#
# The changes are all related to the `service_distribution` and `arrival_distribution` variables below.

# %%
# M/D/1 queue

import scipy.stats as sts


class Queue:
    
    def __init__(self, service_distribution):
        # Store the deterministic service time for an M/D/1 queue
        self.service_distribution = service_distribution
        # We start with an empty queue and the server not busy
        self.people_in_queue = 0
        self.people_being_served = 0

    def add_customer(self, schedule):
        # Add the customer to the queue
        self.people_in_queue += 1
        print(
            f'{schedule.now:5.2f}: Add customer to queue.  '
            f'Queue length: {self.people_in_queue}')
        if self.people_being_served < 1:
            # This customer can be served immediately
            schedule.add_event_after(0, self.start_serving_customer)
            
    def start_serving_customer(self, schedule):
        # Move the customer from the queue to a server
        self.people_in_queue -= 1
        self.people_being_served += 1
        print(
            f'{schedule.now:5.2f}: Start serving customer. '
            f'Queue length: {self.people_in_queue}')
        # Schedule when the server will be done with the customer.
        # Generate a random service time from the service distribution.
        schedule.add_event_after(
            self.service_distribution.rvs(),
            self.finish_serving_customer)
            
    def finish_serving_customer(self, schedule):
        # Remove the customer from the server
        self.people_being_served -= 1
        print(
            f'{schedule.now:5.2f}: Stop serving customer.  '
            f'Queue length: {self.people_in_queue}')
        if self.people_in_queue > 0:
            # There are more people in the queue so serve the next customer
            schedule.add_event_after(0, self.start_serving_customer)


class BusSystem:
    
    def __init__(self, arrival_distribution, service_distribution):
        self.queue = Queue(service_distribution)
        self.arrival_distribution = arrival_distribution

    def add_customer(self, schedule):
        # Add this customer to the queue
        self.queue.add_customer(schedule)
        # Schedule when to add another customer
        schedule.add_event_after(
            self.arrival_distribution.rvs(),
            self.add_customer)

    def run(self, schedule):
        # Schedule when the first customer arrives
        schedule.add_event_after(
            self.arrival_distribution.rvs(),
            self.add_customer)
        

def run_simulation(arrival_distribution, service_distribution, run_until):
    schedule = Schedule()
    bus_system = BusSystem(arrival_distribution, service_distribution)
    bus_system.run(schedule)
    while schedule.next_event_time() < run_until:
        schedule.run_next_event()
    return bus_system

# %% [markdown]
# ## Run an M/D/1 simulation
#
# This is the original distribution with a deterministic service time.

# %%
arrival_rate = 1.2
arrival_distribution = sts.expon(scale=1/arrival_rate)

# This is a trick for getting a deterministic distribution. We
# set the standard deviation of a normal distribution to 0, which
# means all the probability mass is concentrated on the mean and
# every random sample from the distribution will be equal to the mean.
service_rate = 1
service_distribution = sts.norm(loc=1/service_rate, scale=0)

# Run the simulation once
duration = 100
bus_system = run_simulation(arrival_distribution, service_distribution, duration)
print(f'There are {bus_system.queue.people_in_queue} people in the queue')
# Out:
#  1.33: Add customer to queue.  Queue length: 1
#  1.33: Start serving customer. Queue length: 0
#  1.65: Add customer to queue.  Queue length: 1
#  1.78: Add customer to queue.  Queue length: 2
#  1.91: Add customer to queue.  Queue length: 3
#  2.16: Add customer to queue.  Queue length: 4
#  2.33: Stop serving customer.  Queue length: 4
#  2.33: Start serving customer. Queue length: 3
#  2.49: Add customer to queue.  Queue length: 4
#  3.33: Stop serving customer.  Queue length: 4
#  3.33: Start serving customer. Queue length: 3
#  4.33: Stop serving customer.  Queue length: 3
#  4.33: Start serving customer. Queue length: 2
#  4.62: Add customer to queue.  Queue length: 3
#  5.33: Stop serving customer.  Queue length: 3
#  5.33: Start serving customer. Queue length: 2
#  6.17: Add customer to queue.  Queue length: 3
#  6.33: Stop serving customer.  Queue length: 3
#  6.33: Start serving customer. Queue length: 2
#  6.57: Add customer to queue.  Queue length: 3
#  7.33: Stop serving customer.  Queue length: 3
#  7.33: Start serving customer. Queue length: 2
#  7.41: Add customer to queue.  Queue length: 3
#  8.04: Add customer to queue.  Queue length: 4
#  8.33: Stop serving customer.  Queue length: 4
#  8.33: Start serving customer. Queue length: 3
#  9.18: Add customer to queue.  Queue length: 4
#  9.33: Stop serving customer.  Queue length: 4
#  9.33: Start serving customer. Queue length: 3
#  9.33: Add customer to queue.  Queue length: 4
#  9.64: Add customer to queue.  Queue length: 5
# 10.26: Add customer to queue.  Queue length: 6
# 10.33: Stop serving customer.  Queue length: 6
# 10.33: Start serving customer. Queue length: 5
# 10.95: Add customer to queue.  Queue length: 6
# 11.33: Stop serving customer.  Queue length: 6
# 11.33: Start serving customer. Queue length: 5
# 11.77: Add customer to queue.  Queue length: 6
# 12.13: Add customer to queue.  Queue length: 7
# 12.33: Stop serving customer.  Queue length: 7
# 12.33: Start serving customer. Queue length: 6
# 12.54: Add customer to queue.  Queue length: 7
# 13.33: Stop serving customer.  Queue length: 7
# 13.33: Start serving customer. Queue length: 6
# 13.38: Add customer to queue.  Queue length: 7
# 13.43: Add customer to queue.  Queue length: 8
# 13.87: Add customer to queue.  Queue length: 9
# 14.12: Add customer to queue.  Queue length: 10
# 14.33: Stop serving customer.  Queue length: 10
# 14.33: Start serving customer. Queue length: 9
# 14.41: Add customer to queue.  Queue length: 10
# 15.33: Stop serving customer.  Queue length: 10
# 15.33: Start serving customer. Queue length: 9
# 16.33: Stop serving customer.  Queue length: 9
# 16.33: Start serving customer. Queue length: 8
# 17.33: Stop serving customer.  Queue length: 8
# 17.33: Start serving customer. Queue length: 7
# 17.36: Add customer to queue.  Queue length: 8
# 18.33: Stop serving customer.  Queue length: 8
# 18.33: Start serving customer. Queue length: 7
# 18.67: Add customer to queue.  Queue length: 8
# 19.33: Stop serving customer.  Queue length: 8
# 19.33: Start serving customer. Queue length: 7
# 19.36: Add customer to queue.  Queue length: 8
# 20.09: Add customer to queue.  Queue length: 9
# 20.33: Stop serving customer.  Queue length: 9
# 20.33: Start serving customer. Queue length: 8
# 21.07: Add customer to queue.  Queue length: 9
# 21.33: Stop serving customer.  Queue length: 9
# 21.33: Start serving customer. Queue length: 8
# 21.87: Add customer to queue.  Queue length: 9
# 22.33: Stop serving customer.  Queue length: 9
# 22.33: Start serving customer. Queue length: 8
# 23.33: Stop serving customer.  Queue length: 8
# 23.33: Start serving customer. Queue length: 7
# 24.29: Add customer to queue.  Queue length: 8
# 24.33: Stop serving customer.  Queue length: 8
# 24.33: Start serving customer. Queue length: 7
# 25.33: Stop serving customer.  Queue length: 7
# 25.33: Start serving customer. Queue length: 6
# 25.73: Add customer to queue.  Queue length: 7
# 26.33: Stop serving customer.  Queue length: 7
# 26.33: Start serving customer. Queue length: 6
# 27.10: Add customer to queue.  Queue length: 7
# 27.33: Stop serving customer.  Queue length: 7
# 27.33: Start serving customer. Queue length: 6
# 27.33: Add customer to queue.  Queue length: 7
# 28.33: Stop serving customer.  Queue length: 7
# 28.33: Start serving customer. Queue length: 6
# 29.33: Stop serving customer.  Queue length: 6
# 29.33: Start serving customer. Queue length: 5
# 29.72: Add customer to queue.  Queue length: 6
# 29.92: Add customer to queue.  Queue length: 7
# 30.32: Add customer to queue.  Queue length: 8
# 30.33: Stop serving customer.  Queue length: 8
# 30.33: Start serving customer. Queue length: 7
# 31.33: Stop serving customer.  Queue length: 7
# 31.33: Start serving customer. Queue length: 6
# 31.72: Add customer to queue.  Queue length: 7
# 31.87: Add customer to queue.  Queue length: 8
# 32.33: Stop serving customer.  Queue length: 8
# 32.33: Start serving customer. Queue length: 7
# 32.83: Add customer to queue.  Queue length: 8
# 32.96: Add customer to queue.  Queue length: 9
# 33.07: Add customer to queue.  Queue length: 10
# 33.33: Stop serving customer.  Queue length: 10
# 33.33: Start serving customer. Queue length: 9
# 34.33: Stop serving customer.  Queue length: 9
# 34.33: Start serving customer. Queue length: 8
# 34.39: Add customer to queue.  Queue length: 9
# 35.13: Add customer to queue.  Queue length: 10
# 35.33: Stop serving customer.  Queue length: 10
# 35.33: Start serving customer. Queue length: 9
# 36.33: Stop serving customer.  Queue length: 9
# 36.33: Start serving customer. Queue length: 8
# 36.70: Add customer to queue.  Queue length: 9
# 37.19: Add customer to queue.  Queue length: 10
# 37.33: Stop serving customer.  Queue length: 10
# 37.33: Start serving customer. Queue length: 9
# 38.22: Add customer to queue.  Queue length: 10
# 38.25: Add customer to queue.  Queue length: 11
# 38.33: Stop serving customer.  Queue length: 11
# 38.33: Start serving customer. Queue length: 10
# 39.33: Stop serving customer.  Queue length: 10
# 39.33: Start serving customer. Queue length: 9
# 40.33: Stop serving customer.  Queue length: 9
# 40.33: Start serving customer. Queue length: 8
# 40.96: Add customer to queue.  Queue length: 9
# 41.33: Stop serving customer.  Queue length: 9
# 41.33: Start serving customer. Queue length: 8
# 42.33: Stop serving customer.  Queue length: 8
# 42.33: Start serving customer. Queue length: 7
# 43.33: Stop serving customer.  Queue length: 7
# 43.33: Start serving customer. Queue length: 6
# 43.71: Add customer to queue.  Queue length: 7
# 44.33: Stop serving customer.  Queue length: 7
# 44.33: Start serving customer. Queue length: 6
# 45.33: Stop serving customer.  Queue length: 6
# 45.33: Start serving customer. Queue length: 5
# 46.33: Stop serving customer.  Queue length: 5
# 46.33: Start serving customer. Queue length: 4
# 46.61: Add customer to queue.  Queue length: 5
# 47.10: Add customer to queue.  Queue length: 6
# 47.33: Stop serving customer.  Queue length: 6
# 47.33: Start serving customer. Queue length: 5
# 48.33: Stop serving customer.  Queue length: 5
# 48.33: Start serving customer. Queue length: 4
# 49.33: Stop serving customer.  Queue length: 4
# 49.33: Start serving customer. Queue length: 3
# 49.53: Add customer to queue.  Queue length: 4
# 50.07: Add customer to queue.  Queue length: 5
# 50.18: Add customer to queue.  Queue length: 6
# 50.33: Stop serving customer.  Queue length: 6
# 50.33: Start serving customer. Queue length: 5
# 51.33: Stop serving customer.  Queue length: 5
# 51.33: Start serving customer. Queue length: 4
# 51.77: Add customer to queue.  Queue length: 5
# 51.95: Add customer to queue.  Queue length: 6
# 52.13: Add customer to queue.  Queue length: 7
# 52.26: Add customer to queue.  Queue length: 8
# 52.33: Stop serving customer.  Queue length: 8
# 52.33: Start serving customer. Queue length: 7
# 52.76: Add customer to queue.  Queue length: 8
# 53.33: Stop serving customer.  Queue length: 8
# 53.33: Start serving customer. Queue length: 7
# 53.64: Add customer to queue.  Queue length: 8
# 53.91: Add customer to queue.  Queue length: 9
# 54.33: Stop serving customer.  Queue length: 9
# 54.33: Start serving customer. Queue length: 8
# 54.39: Add customer to queue.  Queue length: 9
# 55.33: Stop serving customer.  Queue length: 9
# 55.33: Start serving customer. Queue length: 8
# 56.05: Add customer to queue.  Queue length: 9
# 56.33: Stop serving customer.  Queue length: 9
# 56.33: Start serving customer. Queue length: 8
# 57.33: Stop serving customer.  Queue length: 8
# 57.33: Start serving customer. Queue length: 7
# 58.33: Stop serving customer.  Queue length: 7
# 58.33: Start serving customer. Queue length: 6
# 59.33: Stop serving customer.  Queue length: 6
# 59.33: Start serving customer. Queue length: 5
# 59.80: Add customer to queue.  Queue length: 6
# 60.33: Stop serving customer.  Queue length: 6
# 60.33: Start serving customer. Queue length: 5
# 60.55: Add customer to queue.  Queue length: 6
# 61.33: Stop serving customer.  Queue length: 6
# 61.33: Start serving customer. Queue length: 5
# 61.50: Add customer to queue.  Queue length: 6
# 61.51: Add customer to queue.  Queue length: 7
# 61.73: Add customer to queue.  Queue length: 8
# 62.11: Add customer to queue.  Queue length: 9
# 62.33: Stop serving customer.  Queue length: 9
# 62.33: Start serving customer. Queue length: 8
# 62.45: Add customer to queue.  Queue length: 9
# 62.77: Add customer to queue.  Queue length: 10
# 63.33: Stop serving customer.  Queue length: 10
# 63.33: Start serving customer. Queue length: 9
# 63.90: Add customer to queue.  Queue length: 10
# 64.05: Add customer to queue.  Queue length: 11
# 64.33: Stop serving customer.  Queue length: 11
# 64.33: Start serving customer. Queue length: 10
# 64.61: Add customer to queue.  Queue length: 11
# 65.33: Stop serving customer.  Queue length: 11
# 65.33: Start serving customer. Queue length: 10
# 66.24: Add customer to queue.  Queue length: 11
# 66.33: Stop serving customer.  Queue length: 11
# 66.33: Start serving customer. Queue length: 10
# 67.33: Stop serving customer.  Queue length: 10
# 67.33: Start serving customer. Queue length: 9
# 67.68: Add customer to queue.  Queue length: 10
# 67.78: Add customer to queue.  Queue length: 11
# 67.82: Add customer to queue.  Queue length: 12
# 67.91: Add customer to queue.  Queue length: 13
# 67.96: Add customer to queue.  Queue length: 14
# 68.33: Stop serving customer.  Queue length: 14
# 68.33: Start serving customer. Queue length: 13
# 68.51: Add customer to queue.  Queue length: 14
# 69.33: Stop serving customer.  Queue length: 14
# 69.33: Start serving customer. Queue length: 13
# 70.23: Add customer to queue.  Queue length: 14
# 70.33: Stop serving customer.  Queue length: 14
# 70.33: Start serving customer. Queue length: 13
# 71.33: Stop serving customer.  Queue length: 13
# 71.33: Start serving customer. Queue length: 12
# 71.83: Add customer to queue.  Queue length: 13
# 72.33: Stop serving customer.  Queue length: 13
# 72.33: Start serving customer. Queue length: 12
# 72.95: Add customer to queue.  Queue length: 13
# 73.33: Stop serving customer.  Queue length: 13
# 73.33: Start serving customer. Queue length: 12
# 73.82: Add customer to queue.  Queue length: 13
# 74.33: Stop serving customer.  Queue length: 13
# 74.33: Start serving customer. Queue length: 12
# 74.64: Add customer to queue.  Queue length: 13
# 74.92: Add customer to queue.  Queue length: 14
# 75.20: Add customer to queue.  Queue length: 15
# 75.33: Stop serving customer.  Queue length: 15
# 75.33: Start serving customer. Queue length: 14
# 76.05: Add customer to queue.  Queue length: 15
# 76.33: Stop serving customer.  Queue length: 15
# 76.33: Start serving customer. Queue length: 14
# 76.50: Add customer to queue.  Queue length: 15
# 77.33: Stop serving customer.  Queue length: 15
# 77.33: Start serving customer. Queue length: 14
# 78.33: Stop serving customer.  Queue length: 14
# 78.33: Start serving customer. Queue length: 13
# 78.54: Add customer to queue.  Queue length: 14
# 78.84: Add customer to queue.  Queue length: 15
# 79.33: Stop serving customer.  Queue length: 15
# 79.33: Start serving customer. Queue length: 14
# 80.33: Stop serving customer.  Queue length: 14
# 80.33: Start serving customer. Queue length: 13
# 81.23: Add customer to queue.  Queue length: 14
# 81.33: Stop serving customer.  Queue length: 14
# 81.33: Start serving customer. Queue length: 13
# 82.33: Stop serving customer.  Queue length: 13
# 82.33: Start serving customer. Queue length: 12
# 83.33: Stop serving customer.  Queue length: 12
# 83.33: Start serving customer. Queue length: 11
# 83.97: Add customer to queue.  Queue length: 12
# 84.00: Add customer to queue.  Queue length: 13
# 84.33: Stop serving customer.  Queue length: 13
# 84.33: Start serving customer. Queue length: 12
# 84.41: Add customer to queue.  Queue length: 13
# 84.48: Add customer to queue.  Queue length: 14
# 85.19: Add customer to queue.  Queue length: 15
# 85.33: Stop serving customer.  Queue length: 15
# 85.33: Start serving customer. Queue length: 14
# 85.67: Add customer to queue.  Queue length: 15
# 85.69: Add customer to queue.  Queue length: 16
# 86.33: Stop serving customer.  Queue length: 16
# 86.33: Start serving customer. Queue length: 15
# 87.27: Add customer to queue.  Queue length: 16
# 87.33: Stop serving customer.  Queue length: 16
# 87.33: Start serving customer. Queue length: 15
# 87.48: Add customer to queue.  Queue length: 16
# 88.01: Add customer to queue.  Queue length: 17
# 88.33: Stop serving customer.  Queue length: 17
# 88.33: Start serving customer. Queue length: 16
# 88.65: Add customer to queue.  Queue length: 17
# 88.70: Add customer to queue.  Queue length: 18
# 89.05: Add customer to queue.  Queue length: 19
# 89.33: Stop serving customer.  Queue length: 19
# 89.33: Start serving customer. Queue length: 18
# 90.33: Stop serving customer.  Queue length: 18
# 90.33: Start serving customer. Queue length: 17
# 91.33: Stop serving customer.  Queue length: 17
# 91.33: Start serving customer. Queue length: 16
# 92.33: Stop serving customer.  Queue length: 16
# 92.33: Start serving customer. Queue length: 15
# 92.83: Add customer to queue.  Queue length: 16
# 93.33: Stop serving customer.  Queue length: 16
# 93.33: Start serving customer. Queue length: 15
# 93.93: Add customer to queue.  Queue length: 16
# 94.02: Add customer to queue.  Queue length: 17
# 94.33: Stop serving customer.  Queue length: 17
# 94.33: Start serving customer. Queue length: 16
# 94.63: Add customer to queue.  Queue length: 17
# 94.68: Add customer to queue.  Queue length: 18
# 95.33: Stop serving customer.  Queue length: 18
# 95.33: Start serving customer. Queue length: 17
# 95.36: Add customer to queue.  Queue length: 18
# 96.33: Stop serving customer.  Queue length: 18
# 96.33: Start serving customer. Queue length: 17
# 97.33: Stop serving customer.  Queue length: 17
# 97.33: Start serving customer. Queue length: 16
# 97.36: Add customer to queue.  Queue length: 17
# 98.24: Add customer to queue.  Queue length: 18
# 98.33: Stop serving customer.  Queue length: 18
# 98.33: Start serving customer. Queue length: 17
# 98.72: Add customer to queue.  Queue length: 18
# 99.33: Stop serving customer.  Queue length: 18
# 99.33: Start serving customer. Queue length: 17
# 99.52: Add customer to queue.  Queue length: 18
# There are 18 people in the queue

# %% [markdown]
# ## Run an M/G/1 simulation
#
# We replace the distribution distribution with a more general normal distribution.

# %%
# Exponential with lambda = 1.2
arrival_distribution = sts.expon(scale=1/1.2)

# Normal with mu = 3 and sigma = 1
service_distribution = sts.norm(loc=3, scale=1)

duration = 100
bus_system = run_simulation(arrival_distribution, service_distribution, duration)
print(f'There are {bus_system.queue.people_in_queue} people in the queue')
# Out:
#  1.01: Add customer to queue.  Queue length: 1
#  1.01: Start serving customer. Queue length: 0
#  3.02: Add customer to queue.  Queue length: 1
#  4.06: Stop serving customer.  Queue length: 1
#  4.06: Start serving customer. Queue length: 0
#  5.30: Stop serving customer.  Queue length: 0
#  5.74: Add customer to queue.  Queue length: 1
#  5.74: Start serving customer. Queue length: 0
#  6.67: Add customer to queue.  Queue length: 1
#  8.21: Add customer to queue.  Queue length: 2
#  9.01: Add customer to queue.  Queue length: 3
# 10.43: Stop serving customer.  Queue length: 3
# 10.43: Start serving customer. Queue length: 2
# 11.61: Add customer to queue.  Queue length: 3
# 12.40: Add customer to queue.  Queue length: 4
# 12.54: Add customer to queue.  Queue length: 5
# 13.02: Add customer to queue.  Queue length: 6
# 13.22: Add customer to queue.  Queue length: 7
# 13.33: Add customer to queue.  Queue length: 8
# 14.39: Add customer to queue.  Queue length: 9
# 15.07: Stop serving customer.  Queue length: 9
# 15.07: Start serving customer. Queue length: 8
# 15.50: Add customer to queue.  Queue length: 9
# 16.83: Add customer to queue.  Queue length: 10
# 17.07: Add customer to queue.  Queue length: 11
# 17.65: Add customer to queue.  Queue length: 12
# 17.91: Add customer to queue.  Queue length: 13
# 18.86: Add customer to queue.  Queue length: 14
# 19.68: Stop serving customer.  Queue length: 14
# 19.68: Start serving customer. Queue length: 13
# 20.07: Add customer to queue.  Queue length: 14
# 20.47: Add customer to queue.  Queue length: 15
# 20.62: Add customer to queue.  Queue length: 16
# 23.20: Stop serving customer.  Queue length: 16
# 23.20: Start serving customer. Queue length: 15
# 23.42: Add customer to queue.  Queue length: 16
# 23.75: Add customer to queue.  Queue length: 17
# 25.20: Add customer to queue.  Queue length: 18
# 25.95: Add customer to queue.  Queue length: 19
# 27.63: Stop serving customer.  Queue length: 19
# 27.63: Start serving customer. Queue length: 18
# 28.36: Add customer to queue.  Queue length: 19
# 28.36: Add customer to queue.  Queue length: 20
# 28.93: Add customer to queue.  Queue length: 21
# 29.66: Add customer to queue.  Queue length: 22
# 30.03: Add customer to queue.  Queue length: 23
# 30.30: Add customer to queue.  Queue length: 24
# 30.38: Stop serving customer.  Queue length: 24
# 30.38: Start serving customer. Queue length: 23
# 30.91: Add customer to queue.  Queue length: 24
# 31.53: Add customer to queue.  Queue length: 25
# 31.70: Add customer to queue.  Queue length: 26
# 32.47: Stop serving customer.  Queue length: 26
# 32.47: Start serving customer. Queue length: 25
# 32.71: Add customer to queue.  Queue length: 26
# 34.54: Add customer to queue.  Queue length: 27
# 35.02: Add customer to queue.  Queue length: 28
# 35.25: Add customer to queue.  Queue length: 29
# 35.36: Add customer to queue.  Queue length: 30
# 35.43: Add customer to queue.  Queue length: 31
# 35.73: Add customer to queue.  Queue length: 32
# 35.81: Add customer to queue.  Queue length: 33
# 35.99: Stop serving customer.  Queue length: 33
# 35.99: Start serving customer. Queue length: 32
# 37.58: Add customer to queue.  Queue length: 33
# 38.06: Add customer to queue.  Queue length: 34
# 38.86: Stop serving customer.  Queue length: 34
# 38.86: Start serving customer. Queue length: 33
# 39.79: Add customer to queue.  Queue length: 34
# 40.35: Add customer to queue.  Queue length: 35
# 40.86: Stop serving customer.  Queue length: 35
# 40.86: Start serving customer. Queue length: 34
# 41.68: Add customer to queue.  Queue length: 35
# 43.60: Stop serving customer.  Queue length: 35
# 43.60: Start serving customer. Queue length: 34
# 43.75: Add customer to queue.  Queue length: 35
# 46.63: Stop serving customer.  Queue length: 35
# 46.63: Start serving customer. Queue length: 34
# 47.18: Add customer to queue.  Queue length: 35
# 47.55: Add customer to queue.  Queue length: 36
# 48.40: Add customer to queue.  Queue length: 37
# 48.98: Stop serving customer.  Queue length: 37
# 48.98: Start serving customer. Queue length: 36
# 50.01: Add customer to queue.  Queue length: 37
# 52.19: Add customer to queue.  Queue length: 38
# 52.53: Add customer to queue.  Queue length: 39
# 52.68: Add customer to queue.  Queue length: 40
# 52.76: Stop serving customer.  Queue length: 40
# 52.76: Start serving customer. Queue length: 39
# 53.58: Add customer to queue.  Queue length: 40
# 53.83: Add customer to queue.  Queue length: 41
# 55.83: Add customer to queue.  Queue length: 42
# 56.34: Add customer to queue.  Queue length: 43
# 56.78: Add customer to queue.  Queue length: 44
# 56.80: Stop serving customer.  Queue length: 44
# 56.80: Start serving customer. Queue length: 43
# 57.12: Add customer to queue.  Queue length: 44
# 58.21: Add customer to queue.  Queue length: 45
# 58.51: Add customer to queue.  Queue length: 46
# 59.36: Stop serving customer.  Queue length: 46
# 59.36: Start serving customer. Queue length: 45
# 62.24: Stop serving customer.  Queue length: 45
# 62.24: Start serving customer. Queue length: 44
# 62.41: Add customer to queue.  Queue length: 45
# 62.47: Add customer to queue.  Queue length: 46
# 64.44: Add customer to queue.  Queue length: 47
# 65.25: Stop serving customer.  Queue length: 47
# 65.25: Start serving customer. Queue length: 46
# 67.69: Add customer to queue.  Queue length: 47
# 67.92: Add customer to queue.  Queue length: 48
# 68.01: Stop serving customer.  Queue length: 48
# 68.01: Start serving customer. Queue length: 47
# 68.71: Add customer to queue.  Queue length: 48
# 68.76: Add customer to queue.  Queue length: 49
# 68.92: Add customer to queue.  Queue length: 50
# 69.30: Add customer to queue.  Queue length: 51
# 69.82: Add customer to queue.  Queue length: 52
# 70.79: Add customer to queue.  Queue length: 53
# 70.92: Stop serving customer.  Queue length: 53
# 70.92: Start serving customer. Queue length: 52
# 71.46: Add customer to queue.  Queue length: 53
# 72.08: Stop serving customer.  Queue length: 53
# 72.08: Start serving customer. Queue length: 52
# 73.80: Add customer to queue.  Queue length: 53
# 74.37: Stop serving customer.  Queue length: 53
# 74.37: Start serving customer. Queue length: 52
# 74.39: Add customer to queue.  Queue length: 53
# 76.27: Add customer to queue.  Queue length: 54
# 77.18: Add customer to queue.  Queue length: 55
# 77.42: Stop serving customer.  Queue length: 55
# 77.42: Start serving customer. Queue length: 54
# 77.57: Add customer to queue.  Queue length: 55
# 77.66: Add customer to queue.  Queue length: 56
# 77.80: Add customer to queue.  Queue length: 57
# 78.37: Add customer to queue.  Queue length: 58
# 79.18: Add customer to queue.  Queue length: 59
# 79.29: Add customer to queue.  Queue length: 60
# 79.79: Add customer to queue.  Queue length: 61
# 80.14: Add customer to queue.  Queue length: 62
# 80.33: Stop serving customer.  Queue length: 62
# 80.33: Start serving customer. Queue length: 61
# 80.56: Add customer to queue.  Queue length: 62
# 80.86: Add customer to queue.  Queue length: 63
# 82.34: Add customer to queue.  Queue length: 64
# 83.26: Add customer to queue.  Queue length: 65
# 83.27: Stop serving customer.  Queue length: 65
# 83.27: Start serving customer. Queue length: 64
# 83.36: Add customer to queue.  Queue length: 65
# 86.07: Stop serving customer.  Queue length: 65
# 86.07: Start serving customer. Queue length: 64
# 86.07: Add customer to queue.  Queue length: 65
# 86.55: Add customer to queue.  Queue length: 66
# 86.81: Add customer to queue.  Queue length: 67
# 87.32: Add customer to queue.  Queue length: 68
# 88.64: Add customer to queue.  Queue length: 69
# 89.02: Add customer to queue.  Queue length: 70
# 91.37: Stop serving customer.  Queue length: 70
# 91.37: Start serving customer. Queue length: 69
# 91.47: Add customer to queue.  Queue length: 70
# 92.02: Add customer to queue.  Queue length: 71
# 92.35: Add customer to queue.  Queue length: 72
# 92.53: Add customer to queue.  Queue length: 73
# 92.68: Add customer to queue.  Queue length: 74
# 93.12: Add customer to queue.  Queue length: 75
# 93.60: Stop serving customer.  Queue length: 75
# 93.60: Start serving customer. Queue length: 74
# 93.82: Add customer to queue.  Queue length: 75
# 93.85: Add customer to queue.  Queue length: 76
# 94.33: Add customer to queue.  Queue length: 77
# 94.56: Add customer to queue.  Queue length: 78
# 96.58: Add customer to queue.  Queue length: 79
# 97.36: Add customer to queue.  Queue length: 80
# 97.38: Add customer to queue.  Queue length: 81
# 97.70: Stop serving customer.  Queue length: 81
# 97.70: Start serving customer. Queue length: 80
# 97.97: Add customer to queue.  Queue length: 81
# 98.04: Add customer to queue.  Queue length: 82
# 98.05: Add customer to queue.  Queue length: 83
# 99.04: Add customer to queue.  Queue length: 84
# 99.68: Add customer to queue.  Queue length: 85
# 99.81: Add customer to queue.  Queue length: 86
# There are 86 people in the queue
